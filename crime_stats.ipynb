# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#read data
df = pd.read_csv('datasets/2018CrimeStatisticsByCategoryOfCrime.csv')

#check data
df.head()
# Out:
#   Unnamed: 0             Unnamed: 1 REPORTED CASES           Unnamed: 3  \
# 0        NaN                    NaN            NaN                  NaN
# 1        NaN                    NaN   Totals Cases  Cases under Inquiry
# 2      S/No.  CASE/CRIME INCIDENCES              1                    2
# 3        NaN              HOMICIDES            NaN                  NaN
# 4          1   Death  (by shooting)            190                  117
#
#          Unnamed: 4            Unnamed: 5                 PERFOMANCE  \
# 0               NaN                   NaN                        NaN
# 1  Not Detected/NPW  Cases taken to court  Cases submitted toDPP/RSA
# 2                 3                     4                          5
# 3               NaN                   NaN                        NaN
# 4                29                    44                         74
#
#                Unnamed: 7             Unnamed: 8       Unnamed: 9  ...  \
# ...

# %%
#check for duplicates
df.duplicated().sum()
# Out:
# 0

# %%
#check for missing values
df.isnull().sum()
# Out:
# Unnamed: 0                     32
# Unnamed: 1                      2
# REPORTED CASES                  2
# Unnamed: 3                      2
# Unnamed: 4                      2
# Unnamed: 5                      2
# PERFOMANCE                      2
# Unnamed: 7                      2
# Unnamed: 8                      2
# Unnamed: 9                      2
# Unnamed: 10                     2
# PERSONS TAKEN TO COURT          1
# Unnamed: 12                     3
# Unnamed: 13                     3
# Unnamed: 14                     3
# Unnamed: 15                     1
# Unnamed: 16                     3
# Unnamed: 17                     3
# Unnamed: 18                     3
# Unnamed: 19                    18
# Unnamed: 20                    18
# Unnamed: 21                    18
# SENTENCES IMPOSED BY COURTS    18
# Unnamed: 23                    19
# Unnamed: 24                    19
# Unnamed: 25                    18
# Unnamed: 26                    18
# ...
