# %% [markdown]
# # DATA ANALYSIS WITH PANDAS

# %% [markdown]
# # Series

# %%
# Importing the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
series1 = pd.Series([4, 65, 436, 3, 9])
series2 = pd.Series([7, 0, 3, 897, 9])

comparison_result = series1 == series2
print(comparison_result)
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# dtype: bool

# %%
# Performing operations on series

series1 = pd.Series([2, 4, 6, 8, 14])
series2 = pd.Series([1, 3, 5, 7, 9])

addition_result = series1 + series2
subtraction_result = series1 - series2
multiplication_result = series1 * series2
division_result = series1 / series2

print("Addition:")
print(addition_result)
print("\nSubtraction:")
print(subtraction_result)
print("\nMultiplication:")
print(multiplication_result)
print("\nDivision:")
print(division_result)
# Out:
# Addition:
# 0     3
# 1     7
# 2    11
# 3    15
# 4    23
# dtype: int64
#
# Subtraction:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    5
# dtype: int64
#
# Multiplication:
# 0      2
# 1     12
# 2     30
# 3     56
# 4    126
# dtype: int64
#
# Division:
# 0    2.000000
# 1    1.333333
# 2    1.200000
# 3    1.142857
# 4    1.555556
# dtype: float64

# %%
# Converting a dictionary to a Pandas series
dictionary1 = {'Josh': 24, 'Sam': 36, 'Peace': 19, 'Charles': 65, 'Tom': 44}
series = pd.Series(dictionary1)

print(series)
# Out:
# Josh       24
# Sam        36
# Peace      19
# Charles    65
# Tom        44
# dtype: int64

# %%
# Converting a given series to an array
series = pd.Series(['Love', 800, 'Joy', 789.9, 'Peace', True])
array = np.array(series)

print(array)
# Out:
# ['Love' 800 'Joy' 789.9 'Peace' True]

# %%
# Read the dataset
df = pd.read_csv('datasets/AfricaCupofNationsMatches.csv')

# Get the most frequent value in 'HomeTeamGoals' column
most_frequent = df['HomeTeamGoals'].mode()[0]

# Replace everything else with 'Other'
df['HomeTeamGoals'] = df['HomeTeamGoals'].map(lambda x: x if x == most_frequent else 'Other')

# Display the modified column
print(df['HomeTeamGoals'])
# Out:
# 0        1.0
# 1      Other
# 2      Other
# 3      Other
# 4        1.0
#        ...
# 617    Other
# 618      1.0
# 619    Other
# 620    Other
# 621    Other
# Name: HomeTeamGoals, Length: 622, dtype: object

# %% [markdown]
# # Dataframes

# %%
# Read the given CSV file
df = pd.read_csv('datasets/AfricaCupofNationsMatches.csv')
df
# Out:
#      Year                      Date   Time      HomeTeam       AwayTeam  \
# 0    1957                  10-Feb-57    NaN       Sudan           Egypt
# 1    1957                  10-Feb-57    NaN    Ethiopia    South Africa
# 2    1957                  16-Feb-57    NaN       Egypt        Ethiopia
# 3    1959                  22-May-59    NaN        Egypt       Ethiopia
# 4    1959                  25-May-59    NaN       Sudan        Ethiopia
# ..    ...                        ...    ...          ...            ...
# 617  2019  11 July 2019 (2019-07-11)  21:00  Madagascar         Tunisia
# 618  2019  14 July 2019 (2019-07-14)  18:00     Senegal         Tunisia
# 619  2019  14 July 2019 (2019-07-14)  21:00     Algeria         Nigeria
# 620  2019  17 July 2019 (2019-07-17)  21:00     Tunisia         Nigeria
# 621  2019  19 July 2019 (2019-07-19)  21:00     Senegal         Algeria
#
#      HomeTeamGoals  AwayTeamGoals                 Stage  \
# 0              1.0            2.0            Semifinals
# 1              NaN            NaN            Semifinals
# 2              4.0            0.0                 Final
# 3              4.0            0.0      Final Tournament
# 4              1.0            0.0      Final Tournament
# ..             ...            ...                   ...
# 617            0.0            3.0        Quarter-finals
# 618            1.0            0.0           Semi-finals
# 619            2.0            1.0           Semi-finals
# 620            0.0            1.0  Third place play-off
# 621            0.0            1.0                 Final
#
#                                   SpecialWinConditions  \
# 0                                                  NaN
# 1    Ethiopia  wins due to disqualification of othe...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 617                                                NaN
# 618                              win after extra time
# 619                                                NaN
# 620                                                NaN
# 621                                                NaN
#
#                          Stadium       City  Attendance
# 0              Municipal Stadium   Khartoum     30000.0
# 1                            NaN        NaN         NaN
# 2              Municipal Stadium   Khartoum     30000.0
# 3          Prince Farouk Stadium      Cairo     30000.0
# 4          Prince Farouk Stadium      Cairo     20000.0
# ..                           ...        ...         ...
# 617             Al Salam Stadium      Cairo      7568.0
# 618              30 June Stadium      Cairo      9143.0
# 619  Cairo International Stadium      Cairo     49775.0
# 620             Al Salam Stadium      Cairo      6340.0
# 621  Cairo International Stadium      Cairo     75000.0
#
# [622 rows x 12 columns]

# %%
# Get the first 7 rows of the dataframe
df.head(7)
# Out:
#    Year      Date  Time    HomeTeam       AwayTeam  HomeTeamGoals  \
# 0  1957  10-Feb-57   NaN     Sudan           Egypt            1.0
# 1  1957  10-Feb-57   NaN  Ethiopia    South Africa            NaN
# 2  1957  16-Feb-57   NaN     Egypt        Ethiopia            4.0
# 3  1959  22-May-59   NaN      Egypt       Ethiopia            4.0
# 4  1959  25-May-59   NaN     Sudan        Ethiopia            1.0
# 5  1959  29-May-59   NaN      Egypt          Sudan            2.0
# 6  1962  14-Jan-62   NaN  Ethiopia         Tunisia            4.0
#
#    AwayTeamGoals             Stage  \
# 0            2.0        Semifinals
# 1            NaN        Semifinals
# 2            0.0             Final
# 3            0.0  Final Tournament
# 4            0.0  Final Tournament
# 5            1.0  Final Tournament
# 6            2.0        Semifinals
#
#                                 SpecialWinConditions                 Stadium  \
# 0                                                NaN       Municipal Stadium
# 1  Ethiopia  wins due to disqualification of othe...                     NaN
# 2                                                NaN       Municipal Stadium
# 3                                                NaN   Prince Farouk Stadium
# 4                                                NaN   Prince Farouk Stadium
# 5                                                NaN   Prince Farouk Stadium
# 6                                                NaN  Hailé Sélassié Stadium
#
#            City  Attendance
# 0      Khartoum     30000.0
# 1           NaN         NaN
# 2      Khartoum     30000.0
# 3         Cairo     30000.0
# 4         Cairo     20000.0
# 5         Cairo     30000.0
# 6   Addis Ababa     30000.0

# %%
# Select the ‘HomeTeam’, ‘AwayTeam’, ‘HomeTeamGoals’ and ‘AwayTeamGoals’ columns from your data frame.
selected_columns = df[['HomeTeam', 'AwayTeam', 'HomeTeamGoals', 'AwayTeamGoals']]
print(selected_columns)
# Out:
#         HomeTeam       AwayTeam  HomeTeamGoals  AwayTeamGoals
# 0         Sudan           Egypt            1.0            2.0
# 1      Ethiopia    South Africa            NaN            NaN
# 2         Egypt        Ethiopia            4.0            0.0
# 3          Egypt       Ethiopia            4.0            0.0
# 4         Sudan        Ethiopia            1.0            0.0
# ..           ...            ...            ...            ...
# 617  Madagascar         Tunisia            0.0            3.0
# 618     Senegal         Tunisia            1.0            0.0
# 619     Algeria         Nigeria            2.0            1.0
# 620     Tunisia         Nigeria            0.0            1.0
# 621     Senegal         Algeria            0.0            1.0
#
# [622 rows x 4 columns]

# %%
#Select rows where Egypt appears
egypt_rows = df[df['HomeTeam'] == 'Egypt']
print(egypt_rows)
# Out:
#     Year      Date  Time  HomeTeam   AwayTeam  HomeTeamGoals  AwayTeamGoals  \
# 3   1959  22-May-59   NaN    Egypt   Ethiopia            4.0            0.0
# 5   1959  29-May-59   NaN    Egypt      Sudan            2.0            1.0
# 7   1962  18-Jan-62   NaN    Egypt     Uganda            2.0            1.0
# 13  1963  24-Nov-63   NaN    Egypt    Nigeria            6.0            3.0
# 14  1963  26-Nov-63   NaN    Egypt      Sudan            2.0            2.0
# 16  1963  30-Nov-63   NaN    Egypt   Ethiopia            3.0            0.0
#
#                 Stage SpecialWinConditions                 Stadium  \
# 3    Final Tournament                  NaN   Prince Farouk Stadium
# 5    Final Tournament                  NaN   Prince Farouk Stadium
# 7          Semifinals                  NaN  Hailé Sélassié Stadium
# 13            Group B                  NaN   Kumasi Sports Stadium
# 14            Group B                  NaN   Kumasi Sports Stadium
# 16  Third place match                  NaN    Accra Sports Stadium
#
#             City  Attendance
# 3          Cairo     30000.0
# 5          Cairo     30000.0
# 7    Addis Ababa     30000.0
# 13        Kumasi         NaN
# 14        Kumasi         NaN
# 16         Accra         NaN

# %%
# Count the number of rows and columns in the DataFrame
num_rows, num_columns = df.shape
print("Number of rows:", num_rows)
print("Number of columns:", num_columns)
# Out:
# Number of rows: 622
# Number of columns: 12

# %%
# Select rows where 'Attendance' is missing
missing_attendance_rows = df[df['Attendance'].isnull()]
print(missing_attendance_rows)
# Out:
#      Year                         Date   Time        HomeTeam       AwayTeam  \
# 1    1957                     10-Feb-57    NaN      Ethiopia    South Africa
# 8    1962                     20-Jan-62    NaN       Tunisia          Uganda
# 9    1962                     21-Jan-62    NaN      Ethiopia           Egypt
# 10   1963                     24-Nov-63    NaN         Ghana         Tunisia
# 11   1963                     26-Nov-63    NaN         Ghana        Ethiopia
# ..    ...                           ...    ...            ...            ...
# 565  2017  29 January 2017 (2017-01-29)  20:00         Egypt         Morocco
# 566  2017  1 February 2017 (2017-02-01)  20:00  Burkina Faso           Egypt
# 567  2017  2 February 2017 (2017-02-02)  20:00      Cameroon           Ghana
# 568  2017  4 February 2017 (2017-02-04)  20:00  Burkina Faso           Ghana
# 569  2017  5 February 2017 (2017-02-05)  20:00         Egypt        Cameroon
#
#      HomeTeamGoals  AwayTeamGoals                 Stage  \
# 1              NaN            NaN            Semifinals
# 8              3.0            0.0     Third place match
# 9              4.0            2.0                 Final
# 10             1.0            1.0               Group A
# 11             2.0            0.0               Group A
# ..             ...            ...                   ...
# 565            1.0            0.0        Quarter-finals
# 566            1.0            1.0           Semi-finals
# 567            2.0            0.0           Semi-finals
# 568            1.0            0.0  Third place play-off
# 569            1.0            2.0                 Final
#
#                                   SpecialWinConditions  \
# 1    Ethiopia  wins due to disqualification of othe...
# 8                                                  NaN
# 9                                win after extra time
# 10                                                 NaN
# 11                                                 NaN
# ..                                                 ...
# 565                                                NaN
# 566                        Egypt win on Penalities 3-4
# 567                                                NaN
# 568                                                NaN
# 569                                                NaN
#
#                     Stadium          City  Attendance
# 1                       NaN           NaN         NaN
# 8    Hailé Sélassié Stadium   Addis Ababa         NaN
# 9    Hailé Sélassié Stadium   Addis Ababa         NaN
# 10     Accra Sports Stadium         Accra         NaN
# 11     Accra Sports Stadium         Accra         NaN
# ..                      ...           ...         ...
# 565    Stade de Port-Gentil   Port-Gentil         NaN
# 566       Stade de l'Amitié    Libreville         NaN
# 567    Stade de Franceville   Franceville         NaN
# 568    Stade de Port-Gentil   Port-Gentil         NaN
# 569       Stade de l'Amitié    Libreville         NaN
#
# [100 rows x 12 columns]

# %%
# Select rows where 'HomeTeamGoals' are between 3 and 6 (inclusive)
selected_rows = df[(df['HomeTeamGoals'] >= 3) & (df['HomeTeamGoals'] <= 6)]
print(selected_rows)
# Out:
#      Year                         Date   Time    HomeTeam     AwayTeam  \
# 2    1957                     16-Feb-57    NaN     Egypt      Ethiopia
# 3    1959                     22-May-59    NaN      Egypt     Ethiopia
# 6    1962                     14-Jan-62    NaN  Ethiopia       Tunisia
# 8    1962                     20-Jan-62    NaN   Tunisia        Uganda
# 9    1962                     21-Jan-62    NaN  Ethiopia         Egypt
# ..    ...                           ...    ...        ...          ...
# 553  2017  20 January 2017 (2017-01-20)  20:00   Morocco          Togo
# 585  2019     27 June 2019 (2019-06-27)  22:00     Kenya      Tanzania
# 595  2019     24 June 2019 (2019-06-24)  22:00      Mali    Mauritania
# 608  2019      6 July 2019 (2019-07-06)  18:00   Nigeria      Cameroon
# 611  2019      7 July 2019 (2019-07-07)  21:00   Algeria        Guinea
#
#      HomeTeamGoals  AwayTeamGoals              Stage    SpecialWinConditions  \
# 2              4.0            0.0              Final                     NaN
# 3              4.0            0.0   Final Tournament                     NaN
# 6              4.0            2.0         Semifinals                     NaN
# 8              3.0            0.0  Third place match                     NaN
# 9              4.0            2.0              Final   win after extra time
# ..             ...            ...                ...                     ...
# 553            3.0            1.0            Group C                     NaN
# 585            3.0            2.0            Group C                     NaN
# 595            4.0            1.0            Group E                     NaN
# 608            3.0            2.0        Round of 16                     NaN
# 611            3.0            0.0        Round of 16                     NaN
#
#                     Stadium          City  Attendance
# 2         Municipal Stadium      Khartoum     30000.0
# 3     Prince Farouk Stadium         Cairo     30000.0
# 6    Hailé Sélassié Stadium   Addis Ababa     30000.0
# 8    Hailé Sélassié Stadium   Addis Ababa         NaN
# 9    Hailé Sélassié Stadium   Addis Ababa         NaN
# ..                      ...           ...         ...
# 553            Stade d'Oyem          Oyem         NaN
# 585         30 June Stadium         Cairo      7233.0
# 595            Suez Stadium          Suez      6202.0
# 608      Alexandria Stadium    Alexandria     10000.0
# 611         30 June Stadium         Cairo      8205.0
#
# [138 rows x 12 columns]

# %%
# Change the 'AwayTeamGoals' in the 3rd row to 10
df.at[2, 'AwayTeamGoals'] = 10
print(df)
# Out:
#      Year                      Date   Time      HomeTeam       AwayTeam  \
# 0    1957                  10-Feb-57    NaN       Sudan           Egypt
# 1    1957                  10-Feb-57    NaN    Ethiopia    South Africa
# 2    1957                  16-Feb-57    NaN       Egypt        Ethiopia
# 3    1959                  22-May-59    NaN        Egypt       Ethiopia
# 4    1959                  25-May-59    NaN       Sudan        Ethiopia
# ..    ...                        ...    ...          ...            ...
# 617  2019  11 July 2019 (2019-07-11)  21:00  Madagascar         Tunisia
# 618  2019  14 July 2019 (2019-07-14)  18:00     Senegal         Tunisia
# 619  2019  14 July 2019 (2019-07-14)  21:00     Algeria         Nigeria
# 620  2019  17 July 2019 (2019-07-17)  21:00     Tunisia         Nigeria
# 621  2019  19 July 2019 (2019-07-19)  21:00     Senegal         Algeria
#
#      HomeTeamGoals  AwayTeamGoals                 Stage  \
# 0              1.0            2.0            Semifinals
# 1              NaN            NaN            Semifinals
# 2              4.0           10.0                 Final
# 3              4.0            0.0      Final Tournament
# 4              1.0            0.0      Final Tournament
# ..             ...            ...                   ...
# 617            0.0            3.0        Quarter-finals
# 618            1.0            0.0           Semi-finals
# 619            2.0            1.0           Semi-finals
# 620            0.0            1.0  Third place play-off
# 621            0.0            1.0                 Final
#
#                                   SpecialWinConditions  \
# 0                                                  NaN
# 1    Ethiopia  wins due to disqualification of othe...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 617                                                NaN
# 618                              win after extra time
# 619                                                NaN
# 620                                                NaN
# 621                                                NaN
#
#                          Stadium       City  Attendance
# 0              Municipal Stadium   Khartoum     30000.0
# 1                            NaN        NaN         NaN
# 2              Municipal Stadium   Khartoum     30000.0
# 3          Prince Farouk Stadium      Cairo     30000.0
# 4          Prince Farouk Stadium      Cairo     20000.0
# ..                           ...        ...         ...
# 617             Al Salam Stadium      Cairo      7568.0
# 618              30 June Stadium      Cairo      9143.0
# 619  Cairo International Stadium      Cairo     49775.0
# 620             Al Salam Stadium      Cairo      6340.0
# 621  Cairo International Stadium      Cairo     75000.0
#
# [622 rows x 12 columns]

# %%
# Sort the DataFrame first by 'HomeTeam' in ascending order, then by 'HomeTeamGoals' in descending order
sorted_df = df.sort_values(['HomeTeam', 'HomeTeamGoals'], ascending=[True, False])
print(sorted_df)
# Out:
#      Year                         Date           Time    HomeTeam  \
# 205  1990                      2-Mar-90            NaN   Algeria
# 29   1968                     14-Jan-68            NaN   Algeria
# 135  1980                     16-Mar-80            NaN   Algeria
# 164  1984                      5-Mar-84            NaN   Algeria
# 171  1984                     17-Mar-84            NaN   Algeria
# ..    ...                           ...            ...        ...
# 521  2012                     12-Feb-12  20:30[note 1]    Zambia
# 549  2017  23 January 2017 (2017-01-23)          20:00  Zimbabwe
# 398  2004                     25-Jan-04          16:30  Zimbabwe
# 437  2006                     23-Jan-06          20:00  Zimbabwe
# 575  2019     30 June 2019 (2019-06-30)          21:00  Zimbabwe
#
#          AwayTeam  HomeTeamGoals  AwayTeamGoals              Stage  \
# 205       Nigeria            5.0            1.0            Group A
# 29         Uganda            4.0            0.0            Group A
# 135        Guinea            3.0            2.0            Group B
# 164        Malawi            3.0            0.0            Group B
# 171         Egypt            3.0            1.0  Third place match
# ..            ...            ...            ...                ...
# 521   Ivory Coast            0.0            0.0              Final
# 549       Tunisia            2.0            4.0            Group B
# 398         Egypt            1.0            2.0            Group C
# 437       Senegal            0.0            2.0            Group D
# 575      DR Congo            0.0            4.0            Group A
#
#               SpecialWinConditions                       Stadium  \
# 205                            NaN          Stade 5 Juillet 1962
# 29                             NaN        Hailé Sélassié Stadium
# 135                            NaN               Liberty Stadium
# 164                            NaN                  Stade Bouaké
# 171                            NaN  Stade Félix Houphouët-Boigny
# ..                             ...                           ...
# 521  Zambia  win on Penalities 8-7              Stade d'Angondjé
# 549                            NaN             Stade de l'Amitié
# 398                            NaN          Stade Taïeb El Mhiri
# 437                            NaN             Port Said Stadium
# 575                            NaN               30 June Stadium
#
#              City  Attendance
# 205       Algiers     85000.0
# 29    Addis Ababa     25000.0
# 135        Ibadan     20000.0
# 164        Bouaké     10000.0
# 171       Abidjan       500.0
# ..            ...         ...
# 521    Libreville     40000.0
# 549    Libreville         NaN
# 398          Sfax     22000.0
# 437     Port Said     15000.0
# 575         Cairo      4364.0
#
# [622 rows x 12 columns]

# %%
# Get a list of DataFrame column headers
column_headers = list(df.columns.values)
print(column_headers)
# Out:
# ['Year', 'Date ', 'Time ', 'HomeTeam', 'AwayTeam', 'HomeTeamGoals', 'AwayTeamGoals', 'Stage', 'SpecialWinConditions', 'Stadium', 'City', 'Attendance']

# %%
# Append a column of your choice to the DataFrame
df['City'] = 'Kampala'
print(df)
# Out:
#      Year                      Date   Time      HomeTeam       AwayTeam  \
# 0    1957                  10-Feb-57    NaN       Sudan           Egypt
# 1    1957                  10-Feb-57    NaN    Ethiopia    South Africa
# 2    1957                  16-Feb-57    NaN       Egypt        Ethiopia
# 3    1959                  22-May-59    NaN        Egypt       Ethiopia
# 4    1959                  25-May-59    NaN       Sudan        Ethiopia
# ..    ...                        ...    ...          ...            ...
# 617  2019  11 July 2019 (2019-07-11)  21:00  Madagascar         Tunisia
# 618  2019  14 July 2019 (2019-07-14)  18:00     Senegal         Tunisia
# 619  2019  14 July 2019 (2019-07-14)  21:00     Algeria         Nigeria
# 620  2019  17 July 2019 (2019-07-17)  21:00     Tunisia         Nigeria
# 621  2019  19 July 2019 (2019-07-19)  21:00     Senegal         Algeria
#
#      HomeTeamGoals  AwayTeamGoals                 Stage  \
# 0              1.0            2.0            Semifinals
# 1              NaN            NaN            Semifinals
# 2              4.0           10.0                 Final
# 3              4.0            0.0      Final Tournament
# 4              1.0            0.0      Final Tournament
# ..             ...            ...                   ...
# 617            0.0            3.0        Quarter-finals
# 618            1.0            0.0           Semi-finals
# 619            2.0            1.0           Semi-finals
# 620            0.0            1.0  Third place play-off
# 621            0.0            1.0                 Final
#
#                                   SpecialWinConditions  \
# 0                                                  NaN
# 1    Ethiopia  wins due to disqualification of othe...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 617                                                NaN
# 618                              win after extra time
# 619                                                NaN
# 620                                                NaN
# 621                                                NaN
#
#                          Stadium     City  Attendance
# 0              Municipal Stadium  Kampala     30000.0
# 1                            NaN  Kampala         NaN
# 2              Municipal Stadium  Kampala     30000.0
# 3          Prince Farouk Stadium  Kampala     30000.0
# 4          Prince Farouk Stadium  Kampala     20000.0
# ..                           ...      ...         ...
# 617             Al Salam Stadium  Kampala      7568.0
# 618              30 June Stadium  Kampala      9143.0
# 619  Cairo International Stadium  Kampala     49775.0
# 620             Al Salam Stadium  Kampala      6340.0
# 621  Cairo International Stadium  Kampala     75000.0
#
# [622 rows x 12 columns]

# %%
# Add 2 rows to the DataFrame
df = df.append([{'HomeTeam': 'Algeria', 'AwayTeam': 'Kenya', 'HomeTeamGoals': 2, 'AwayTeamGoals': 1, 'Attendance': 50000, 'City': 'Kampala'},
                {'HomeTeam': 'Uganda', 'AwayTeam': 'Tanzania', 'HomeTeamGoals': 3, 'AwayTeamGoals': 0, 'Attendance': 60000, 'City': 'Kampala'}],
               ignore_index=True)
print(df)
# Out:
#        Year                      Date   Time    HomeTeam       AwayTeam  \
# 0    1957.0                  10-Feb-57    NaN     Sudan           Egypt
# 1    1957.0                  10-Feb-57    NaN  Ethiopia    South Africa
# 2    1957.0                  16-Feb-57    NaN     Egypt        Ethiopia
# 3    1959.0                  22-May-59    NaN      Egypt       Ethiopia
# 4    1959.0                  25-May-59    NaN     Sudan        Ethiopia
# ..      ...                        ...    ...        ...            ...
# 619  2019.0  14 July 2019 (2019-07-14)  21:00   Algeria         Nigeria
# 620  2019.0  17 July 2019 (2019-07-17)  21:00   Tunisia         Nigeria
# 621  2019.0  19 July 2019 (2019-07-19)  21:00   Senegal         Algeria
# 622     NaN                        NaN    NaN    Algeria          Kenya
# 623     NaN                        NaN    NaN     Uganda       Tanzania
#
#      HomeTeamGoals  AwayTeamGoals                 Stage  \
# 0              1.0            2.0            Semifinals
# 1              NaN            NaN            Semifinals
# 2              4.0           10.0                 Final
# 3              4.0            0.0      Final Tournament
# 4              1.0            0.0      Final Tournament
# ..             ...            ...                   ...
# 619            2.0            1.0           Semi-finals
# 620            0.0            1.0  Third place play-off
# 621            0.0            1.0                 Final
# 622            2.0            1.0                   NaN
# 623            3.0            0.0                   NaN
#
#                                   SpecialWinConditions  \
# 0                                                  NaN
# 1    Ethiopia  wins due to disqualification of othe...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 619                                                NaN
# 620                                                NaN
# 621                                                NaN
# 622                                                NaN
# 623                                                NaN
#
#                          Stadium     City  Attendance
# 0              Municipal Stadium  Kampala     30000.0
# 1                            NaN  Kampala         NaN
# 2              Municipal Stadium  Kampala     30000.0
# 3          Prince Farouk Stadium  Kampala     30000.0
# 4          Prince Farouk Stadium  Kampala     20000.0
# ..                           ...      ...         ...
# 619  Cairo International Stadium  Kampala     49775.0
# 620             Al Salam Stadium  Kampala      6340.0
# 621  Cairo International Stadium  Kampala     75000.0
# 622                          NaN  Kampala     50000.0
# 623                          NaN  Kampala     60000.0
#
# [624 rows x 12 columns]
# /tmp/ipykernel_26607/3708176271.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append([{'HomeTeam': 'Algeria', 'AwayTeam': 'Kenya', 'HomeTeamGoals': 2, 'AwayTeamGoals': 1, 'Attendance': 50000, 'City': 'Kampala'},

# %%
# Change the country 'Uganda' to 'China' in the 'AwayTeam' column
df.loc[df['AwayTeam'] == 'Uganda', 'AwayTeam'] = 'China'
print(df)
# Out:
#        Year                      Date   Time    HomeTeam       AwayTeam  \
# 0    1957.0                  10-Feb-57    NaN     Sudan           Egypt
# 1    1957.0                  10-Feb-57    NaN  Ethiopia    South Africa
# 2    1957.0                  16-Feb-57    NaN     Egypt        Ethiopia
# 3    1959.0                  22-May-59    NaN      Egypt       Ethiopia
# 4    1959.0                  25-May-59    NaN     Sudan        Ethiopia
# ..      ...                        ...    ...        ...            ...
# 619  2019.0  14 July 2019 (2019-07-14)  21:00   Algeria         Nigeria
# 620  2019.0  17 July 2019 (2019-07-17)  21:00   Tunisia         Nigeria
# 621  2019.0  19 July 2019 (2019-07-19)  21:00   Senegal         Algeria
# 622     NaN                        NaN    NaN    Algeria          Kenya
# 623     NaN                        NaN    NaN     Uganda       Tanzania
#
#      HomeTeamGoals  AwayTeamGoals                 Stage  \
# 0              1.0            2.0            Semifinals
# 1              NaN            NaN            Semifinals
# 2              4.0           10.0                 Final
# 3              4.0            0.0      Final Tournament
# 4              1.0            0.0      Final Tournament
# ..             ...            ...                   ...
# 619            2.0            1.0           Semi-finals
# 620            0.0            1.0  Third place play-off
# 621            0.0            1.0                 Final
# 622            2.0            1.0                   NaN
# 623            3.0            0.0                   NaN
#
#                                   SpecialWinConditions  \
# 0                                                  NaN
# 1    Ethiopia  wins due to disqualification of othe...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 619                                                NaN
# 620                                                NaN
# 621                                                NaN
# 622                                                NaN
# 623                                                NaN
#
#                          Stadium     City  Attendance
# 0              Municipal Stadium  Kampala     30000.0
# 1                            NaN  Kampala         NaN
# 2              Municipal Stadium  Kampala     30000.0
# 3          Prince Farouk Stadium  Kampala     30000.0
# 4          Prince Farouk Stadium  Kampala     20000.0
# ..                           ...      ...         ...
# 619  Cairo International Stadium  Kampala     49775.0
# 620             Al Salam Stadium  Kampala      6340.0
# 621  Cairo International Stadium  Kampala     75000.0
# 622                          NaN  Kampala     50000.0
# 623                          NaN  Kampala     60000.0
#
# [624 rows x 12 columns]

# %%
# Reset the index in the DataFrame
df = df.reset_index(drop=True)
print(df)
# Out:
#        Year                      Date   Time    HomeTeam       AwayTeam  \
# 0    1957.0                  10-Feb-57    NaN     Sudan           Egypt
# 1    1957.0                  10-Feb-57    NaN  Ethiopia    South Africa
# 2    1957.0                  16-Feb-57    NaN     Egypt        Ethiopia
# 3    1959.0                  22-May-59    NaN      Egypt       Ethiopia
# 4    1959.0                  25-May-59    NaN     Sudan        Ethiopia
# ..      ...                        ...    ...        ...            ...
# 619  2019.0  14 July 2019 (2019-07-14)  21:00   Algeria         Nigeria
# 620  2019.0  17 July 2019 (2019-07-17)  21:00   Tunisia         Nigeria
# 621  2019.0  19 July 2019 (2019-07-19)  21:00   Senegal         Algeria
# 622     NaN                        NaN    NaN    Algeria          Kenya
# 623     NaN                        NaN    NaN     Uganda       Tanzania
#
#      HomeTeamGoals  AwayTeamGoals                 Stage  \
# 0              1.0            2.0            Semifinals
# 1              NaN            NaN            Semifinals
# 2              4.0           10.0                 Final
# 3              4.0            0.0      Final Tournament
# 4              1.0            0.0      Final Tournament
# ..             ...            ...                   ...
# 619            2.0            1.0           Semi-finals
# 620            0.0            1.0  Third place play-off
# 621            0.0            1.0                 Final
# 622            2.0            1.0                   NaN
# 623            3.0            0.0                   NaN
#
#                                   SpecialWinConditions  \
# 0                                                  NaN
# 1    Ethiopia  wins due to disqualification of othe...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 619                                                NaN
# 620                                                NaN
# 621                                                NaN
# 622                                                NaN
# 623                                                NaN
#
#                          Stadium     City  Attendance
# 0              Municipal Stadium  Kampala     30000.0
# 1                            NaN  Kampala         NaN
# 2              Municipal Stadium  Kampala     30000.0
# 3          Prince Farouk Stadium  Kampala     30000.0
# 4          Prince Farouk Stadium  Kampala     20000.0
# ..                           ...      ...         ...
# 619  Cairo International Stadium  Kampala     49775.0
# 620             Al Salam Stadium  Kampala      6340.0
# 621  Cairo International Stadium  Kampala     75000.0
# 622                          NaN  Kampala     50000.0
# 623                          NaN  Kampala     60000.0
#
# [624 rows x 12 columns]

# %%
# Check whether the 'Stadium' column is present in the DataFrame or not
if 'Stadium' in df.columns:
    print("The 'Stadium' column is present in the DataFrame")
else:
    print("The 'Stadium' column is not present in the DataFrame")
# Out:
# The 'Stadium' column is present in the DataFrame

# %%
# Convert the datatype of the 'AwayTeamGoals' column from integer to float
df['AwayTeamGoals'] = df['AwayTeamGoals'].astype(float)
print(df.dtypes)
# Out:
# Year                    float64
# Date                     object
# Time                     object
# HomeTeam                 object
# AwayTeam                 object
# HomeTeamGoals           float64
# AwayTeamGoals           float64
# Stage                    object
# SpecialWinConditions     object
# Stadium                  object
# City                     object
# Attendance              float64
# dtype: object

# %%
# Remove the last 10 rows from the DataFrame
df = df[:-10]
print(df)
# Out:
#        Year                     Date   Time      HomeTeam       AwayTeam  \
# 0    1957.0                 10-Feb-57    NaN       Sudan           Egypt
# 1    1957.0                 10-Feb-57    NaN    Ethiopia    South Africa
# 2    1957.0                 16-Feb-57    NaN       Egypt        Ethiopia
# 3    1959.0                 22-May-59    NaN        Egypt       Ethiopia
# 4    1959.0                 25-May-59    NaN       Sudan        Ethiopia
# ..      ...                       ...    ...          ...            ...
# 609  2019.0  6 July 2019 (2019-07-06)  21:00       Egypt    South Africa
# 610  2019.0  7 July 2019 (2019-07-07)  18:00  Madagascar        DR Congo
# 611  2019.0  7 July 2019 (2019-07-07)  21:00     Algeria          Guinea
# 612  2019.0  8 July 2019 (2019-07-08)  18:00        Mali     Ivory Coast
# 613  2019.0  8 July 2019 (2019-07-08)  21:00       Ghana         Tunisia
#
#      HomeTeamGoals  AwayTeamGoals             Stage  \
# 0              1.0            2.0        Semifinals
# 1              NaN            NaN        Semifinals
# 2              4.0           10.0             Final
# 3              4.0            0.0  Final Tournament
# 4              1.0            0.0  Final Tournament
# ..             ...            ...               ...
# 609            0.0            1.0       Round of 16
# 610            2.0            2.0       Round of 16
# 611            3.0            0.0       Round of 16
# 612            0.0            1.0       Round of 16
# 613            1.0            1.0       Round of 16
#
#                                   SpecialWinConditions  \
# 0                                                  NaN
# 1    Ethiopia  wins due to disqualification of othe...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 609                                                NaN
# 610                  Madagascar  win on Penalities 4-2
# 611                                                NaN
# 612                                                NaN
# 613                      Tunisia win on Penalities 4-5
#
#                          Stadium     City  Attendance
# 0              Municipal Stadium  Kampala     30000.0
# 1                            NaN  Kampala         NaN
# 2              Municipal Stadium  Kampala     30000.0
# 3          Prince Farouk Stadium  Kampala     30000.0
# 4          Prince Farouk Stadium  Kampala     20000.0
# ..                           ...      ...         ...
# 609  Cairo International Stadium  Kampala     75000.0
# 610           Alexandria Stadium  Kampala      5890.0
# 611              30 June Stadium  Kampala      8205.0
# 612                 Suez Stadium  Kampala      7672.0
# 613             Ismailia Stadium  Kampala      8890.0
#
# [614 rows x 12 columns]

# %%
# Iterate over rows in the DataFrame
for index, row in df.iterrows():
    print(row['HomeTeam'], row['AwayTeam'], row['HomeTeamGoals'], row['AwayTeamGoals'], row['Attendance'], row['City'])
# Out:
# Sudan   Egypt 1.0 2.0 30000.0 Kampala
# Ethiopia   South Africa nan nan nan Kampala
# Egypt   Ethiopia 4.0 10.0 30000.0 Kampala
# Egypt  Ethiopia 4.0 0.0 30000.0 Kampala
# Sudan   Ethiopia 1.0 0.0 20000.0 Kampala
# Egypt  Sudan 2.0 1.0 30000.0 Kampala
# Ethiopia   Tunisia 4.0 2.0 30000.0 Kampala
# Egypt  Uganda 2.0 1.0 30000.0 Kampala
# Tunisia   Uganda 3.0 0.0 nan Kampala
# Ethiopia  Egypt 4.0 2.0 nan Kampala
# Ghana   Tunisia 1.0 1.0 nan Kampala
# Ghana   Ethiopia 2.0 0.0 nan Kampala
# Ethiopia   Tunisia 4.0 2.0 nan Kampala
# Egypt  Nigeria 6.0 3.0 nan Kampala
# Egypt  Sudan 2.0 2.0 nan Kampala
# Sudan   Nigeria 4.0 0.0 nan Kampala
# Egypt  Ethiopia 3.0 0.0 nan Kampala
# Ghana   Sudan 3.0 0.0 nan Kampala
# Tunisia   Ethiopia 4.0 0.0 16000.0 Kampala
# Senegal   Tunisia 0.0 0.0 nan Kampala
# Senegal   Ethiopia 5.0 1.0 nan Kampala
# Ghana   Congo-Léopoldville 5.0 2.0 nan Kampala
# Ivory Coast   Congo-Léopoldville 3.0 0.0 nan Kampala
# Ghana   Ivory Coast 4.0 1.0 nan Kampala
# Senegal   Ivory Coast 0.0 1.0 nan Kampala
# Ghana   Tunisia 3.0 2.0 nan Kampala
# Ethiopia   Uganda 2.0 1.0 20000.0 Kampala
# Ivory Coast   Algeria 3.0 0.0 20000.0 Kampala
# Ethiopia   Ivory Coast 1.0 0.0 25000.0 Kampala
# Algeria   Uganda 4.0 0.0 25000.0 Kampala
# Ivory Coast   Uganda 2.0 1.0 15000.0 Kampala
# Ethiopia   Algeria 3.0 1.0 20000.0 Kampala
# Ghana   Senegal 2.0 2.0 3000.0 Kampala
# Congo-Kinshasa   Congo-Brazzaville 3.0 0.0 4000.0 Kampala
# Senegal   Congo-Brazzaville 2.0 1.0 3000.0 Kampala
# Ghana   Congo-Kinshasa 2.0 1.0 3000.0 Kampala
# Congo-Kinshasa   Senegal 2.0 1.0 3000.0 Kampala
# Ghana   Congo-Brazzaville 3.0 1.0 3000.0 Kampala
# Ethiopia   Congo-Kinshasa 2.0 3.0 25000.0 Kampala
# Ghana   Ivory Coast 4.0 3.0 5000.0 Kampala
# Ivory Coast   Ethiopia 1.0 0.0 10000.0 Kampala
# Congo-Kinshasa   Ghana 1.0 0.0 25000.0 Kampala
# Cameroon   Ivory Coast 3.0 2.0 14464.0 Kampala
# Sudan   Ethiopia 3.0 0.0 14464.0 Kampala
# Cameroon   Ethiopia 3.0 2.0 9864.0 Kampala
# Ivory Coast   Sudan 1.0 0.0 9864.0 Kampala
# Ivory Coast   Ethiopia 6.0 1.0 9770.0 Kampala
# Sudan   Cameroon 2.0 1.0 9770.0 Kampala
# Ghana   Congo-Kinshasa 2.0 0.0 7525.0 Kampala
# United Arab Rep.   Guinea 4.0 1.0 7525.0 Kampala
# Congo-Kinshasa   Guinea 2.0 2.0 3342.0 Kampala
# United Arab Rep.   Ghana 1.0 1.0 3342.0 Kampala
# Guinea   Ghana 1.0 1.0 3927.0 Kampala
# United Arab Rep.   Congo-Kinshasa 1.0 0.0 3927.0 Kampala
# Ivory Coast   Ghana 1.0 2.0 12350.0 Kampala
# United Arab Rep.   Sudan 1.0 2.0 12350.0 Kampala
# United Arab Rep.   Ivory Coast 3.0 1.0 12187.0 Kampala
# Sudan   Ghana 1.0 0.0 102187.0 Kampala
# Cameroon   Kenya 2.0 1.0 40000.0 Kampala
# Mali   Togo 3.0 3.0 nan Kampala
# Mali   Kenya 1.0 1.0 nan Kampala
# Cameroon   Togo 2.0 0.0 nan Kampala
# Togo   Kenya 1.0 1.0 nan Kampala
# Cameroon   Mali 1.0 1.0 nan Kampala
# Congo   Morocco 1.0 1.0 nan Kampala
# Zaire   Sudan 1.0 1.0 nan Kampala
# Morocco   Sudan 1.0 1.0 nan Kampala
# Zaire   Congo 2.0 0.0 nan Kampala
# Morocco   Zaire 1.0 1.0 nan Kampala
# Congo   Sudan 4.0 2.0 nan Kampala
# Cameroon   Congo 0.0 1.0 nan Kampala
# Zaire   Mali 3.0 4.0 nan Kampala
# Cameroon   Zaire 5.0 2.0 nan Kampala
# Congo   Mali 3.0 2.0 nan Kampala
# Egypt   Uganda 2.0 1.0 5000.0 Kampala
# Zambia   Ivory Coast 1.0 0.0 1000.0 Kampala
# Egypt   Zambia 3.0 1.0 nan Kampala
# Ivory Coast   Uganda 2.0 2.0 nan Kampala
# Egypt   Ivory Coast 2.0 0.0 nan Kampala
# Zambia   Uganda 1.0 0.0 nan Kampala
# Zaire   Guinea 2.0 1.0 nan Kampala
# Congo   Mauritius 2.0 0.0 nan Kampala
# Guinea   Mauritius 2.0 1.0 nan Kampala
# Congo   Zaire 2.0 1.0 nan Kampala
# Congo   Guinea 1.0 1.0 nan Kampala
# Zaire   Mauritius 4.0 1.0 nan Kampala
# Egypt   Zaire 2.0 3.0 nan Kampala
# Congo   Zambia 2.0 4.0 nan Kampala
# Congo   Egypt 0.0 4.0 nan Kampala
# Zaire   Zambia 2.0 2.0 nan Kampala
# Zaire   Zambia 2.0 0.0 nan Kampala
# Ethiopia   Uganda 2.0 0.0 30000.0 Kampala
# Egypt   Guinea 1.0 1.0 nan Kampala
# Egypt   Uganda 2.0 1.0 nan Kampala
# Ethiopia   Guinea 1.0 2.0 nan Kampala
# Guinea   Uganda 2.0 1.0 nan Kampala
# Ethiopia   Egypt 1.0 1.0 nan Kampala
# Nigeria   Zaire 4.0 2.0 nan Kampala
# Morocco   Sudan 2.0 2.0 nan Kampala
# Nigeria   Sudan 1.0 0.0 nan Kampala
# Morocco   Zaire 1.0 0.0 nan Kampala
# Morocco   Nigeria 3.0 1.0 nan Kampala
# Zaire   Sudan 1.0 1.0 nan Kampala
# Guinea   Nigeria 1.0 1.0 nan Kampala
# Morocco   Egypt 2.0 1.0 nan Kampala
# Morocco   Nigeria 2.0 1.0 nan Kampala
# Guinea   Egypt 4.0 2.0 nan Kampala
# Nigeria   Egypt 3.0 2.0 nan Kampala
# Guinea   Morocco 1.0 1.0 nan Kampala
# Ghana   Zambia 2.0 1.0 50000.0 Kampala
# Nigeria   Upper Volta 4.0 2.0 50000.0 Kampala
# Zambia   Upper Volta 2.0 0.0 60000.0 Kampala
# Nigeria   Ghana 1.0 1.0 60000.0 Kampala
# Zambia   Nigeria 0.0 0.0 25000.0 Kampala
# Ghana   Upper Volta 3.0 0.0 25000.0 Kampala
# Morocco   Tunisia 1.0 1.0 50000.0 Kampala
# Uganda   Congo 3.0 1.0 50000.0 Kampala
# Tunisia   Uganda 3.0 1.0 20000.0 Kampala
# Morocco   Congo 1.0 0.0 20000.0 Kampala
# Congo   Tunisia 0.0 0.0 10000.0 Kampala
# Uganda   Morocco 3.0 0.0 10000.0 Kampala
# Ghana   Tunisia 1.0 0.0 40000.0 Kampala
# Uganda   Nigeria 2.0 1.0 nan Kampala
# Nigeria   Tunisia 1.0 11.0 nan Kampala
# Ghana   Uganda 2.0 0.0 nan Kampala
# Nigeria   Tanzania 3.0 1.0 80000.0 Kampala
# Egypt   Ivory Coast 2.0 1.0 80000.0 Kampala
# Egypt   Tanzania 2.0 1.0 55000.0 Kampala
# Nigeria   Ivory Coast 0.0 0.0 55000.0 Kampala
# Ivory Coast   Tanzania 1.0 1.0 70000.0 Kampala
# Nigeria   Egypt 1.0 0.0 70000.0 Kampala
# Ghana   Algeria 0.0 0.0 40000.0 Kampala
# Morocco   Guinea 1.0 1.0 40000.0 Kampala
# Algeria   Morocco 1.0 0.0 20000.0 Kampala
# Ghana   Guinea 1.0 0.0 20000.0 Kampala
# Algeria   Guinea 3.0 2.0 20000.0 Kampala
# Morocco   Ghana 1.0 0.0 20000.0 Kampala
# Nigeria   Morocco 1.0 0.0 70000.0 Kampala
# Algeria   Egypt 2.0 2.0 5000.0 Kampala
# Morocco   Egypt 2.0 0.0 5000.0 Kampala
# Nigeria   Algeria 3.0 0.0 85000.0 Kampala
# Libya   Ghana 2.0 2.0 45200.0 Kampala
# Cameroon   Tunisia 1.0 1.0 45000.0 Kampala
# Cameroon   Ghana 0.0 0.0 40000.0 Kampala
# Libya   Tunisia 2.0 0.0 40000.0 Kampala
# Ghana   Tunisia 1.0 0.0 40000.0 Kampala
# Libya   Cameroon 0.0 0.0 40000.0 Kampala
# Nigeria   Ethiopia 3.0 0.0 5000.0 Kampala
# Algeria   Zambia 1.0 0.0 5000.0 Kampala
# Zambia   Ethiopia 1.0 0.0 5000.0 Kampala
# Algeria   Nigeria 2.0 1.0 5000.0 Kampala
# Algeria   Ethiopia 0.0 0.0 5000.0 Kampala
# Zambia   Nigeria 3.0 0.0 5000.0 Kampala
# Ghana   Algeria 3.0 2.0 5000.0 Kampala
# Libya   Zambia 2.0 1.0 50000.0 Kampala
# Zambia   Algeria 2.0 0.0 2000.0 Kampala
# Ghana   Libya 1.0 1.0 50000.0 Kampala
# Ivory Coast   Togo 3.0 0.0 50000.0 Kampala
# Egypt   Cameroon 1.0 0.0 50000.0 Kampala
# Cameroon   Togo 4.0 1.0 15000.0 Kampala
# Ivory Coast   Egypt 1.0 2.0 40000.0 Kampala
# Egypt   Togo 0.0 0.0 40000.0 Kampala
# Ivory Coast   Cameroon 0.0 2.0 40000.0 Kampala
# Ghana   Nigeria 1.0 2.0 10000.0 Kampala
# Algeria   Malawi 3.0 0.0 10000.0 Kampala
# Malawi   Nigeria 2.0 2.0 15000.0 Kampala
# Algeria   Ghana 2.0 0.0 15000.0 Kampala
# Algeria   Nigeria 0.0 0.0 3000.0 Kampala
# Ghana   Malawi 1.0 0.0 3000.0 Kampala
# Egypt   Nigeria 2.0 2.0 15000.0 Kampala
# Algeria   Cameroon 0.0 0.0 15000.0 Kampala
# Algeria   Egypt 3.0 1.0 500.0 Kampala
# Cameroon   Nigeria 3.0 1.0 27456.0 Kampala
# Senegal   Egypt 1.0 0.0 45000.0 Kampala
# Ivory Coast   Mozambique 3.0 0.0 20000.0 Kampala
# Senegal   Mozambique 2.0 0.0 30000.0 Kampala
# Egypt   Ivory Coast 2.0 0.0 50000.0 Kampala
# Ivory Coast   Senegal 1.0 0.0 15000.0 Kampala
# Egypt   Mozambique 2.0 0.0 55000.0 Kampala
# Algeria   Morocco 0.0 0.0 12000.0 Kampala
# Cameroon   Zambia 3.0 2.0 20000.0 Kampala
# Algeria   Zambia 0.0 0.0 4000.0 Kampala
# Cameroon   Morocco 1.0 1.0 8000.0 Kampala
# Morocco   Zambia 1.0 0.0 5000.0 Kampala
# Cameroon   Algeria 3.0 2.0 10000.0 Kampala
# Cameroon   Ivory Coast 1.0 0.0 12000.0 Kampala
# Egypt   Morocco 1.0 0.0 95000.0 Kampala
# Ivory Coast   Morocco 3.0 2.0 1000.0 Kampala
# Egypt   Cameroon 0.0 0.0 120000.0 Kampala
# Morocco   Zaire 1.0 1.0 80000.0 Kampala
# Ivory Coast   Algeria 1.0 1.0 40000.0 Kampala
# Ivory Coast   Zaire 1.0 1.0 45000.0 Kampala
# Morocco   Algeria 1.0 0.0 78000.0 Kampala
# Algeria   Zaire 1.0 0.0 75000.0 Kampala
# Morocco   Ivory Coast 0.0 0.0 80000.0 Kampala
# Cameroon   Egypt 1.0 0.0 5000.0 Kampala
# Nigeria   Kenya 3.0 0.0 4000.0 Kampala
# Cameroon   Nigeria 1.0 1.0 13000.0 Kampala
# Egypt   Kenya 3.0 0.0 12000.0 Kampala
# Cameroon   Kenya 0.0 0.0 25000.0 Kampala
# Nigeria   Egypt 0.0 0.0 30000.0 Kampala
# Nigeria   Algeria 1.0 1.0 35000.0 Kampala
# Morocco   Cameroon 0.0 1.0 45000.0 Kampala
# Morocco   Algeria 1.0 1.0 10000.0 Kampala
# Cameroon   Nigeria 1.0 0.0 50000.0 Kampala
# Algeria   Nigeria 5.0 1.0 85000.0 Kampala
# Ivory Coast   Egypt 3.0 1.0 14000.0 Kampala
# Nigeria   Egypt 1.0 0.0 47000.0 Kampala
# Algeria   Ivory Coast 3.0 0.0 86000.0 Kampala
# Nigeria   Ivory Coast 1.0 0.0 86000.0 Kampala
# Algeria   Egypt 2.0 0.0 86000.0 Kampala
# Zambia   Cameroon 1.0 0.0 25000.0 Kampala
# Senegal   Kenya 0.0 0.0 13000.0 Kampala
# Zambia   Kenya 1.0 0.0 11000.0 Kampala
# Senegal   Cameroon 2.0 0.0 22000.0 Kampala
# Zambia   Senegal 0.0 0.0 18000.0 Kampala
# Cameroon   Kenya 2.0 0.0 13000.0 Kampala
# Zambia   Nigeria 0.0 2.0 27000.0 Kampala
# Algeria   Senegal 2.0 1.0 88000.0 Kampala
# Zambia   Senegal 1.0 0.0 33000.0 Kampala
# Algeria   Nigeria 1.0 0.0 105032.0 Kampala
# Nigeria   Senegal 2.0 1.0 60000.0 Kampala
# Nigeria   Kenya 2.0 1.0 5000.0 Kampala
# Senegal   Kenya 3.0 0.0 50000.0 Kampala
# Cameroon   Morocco 1.0 0.0 60000.0 Kampala
# Morocco   Zaire 1.0 1.0 5000.0 Kampala
# Cameroon   Zaire 1.0 1.0 10000.0 Kampala
# Ivory Coast   Algeria 3.0 0.0 5000.0 Kampala
# Ivory Coast   Congo 0.0 0.0 5000.0 Kampala
# Algeria   Congo 1.0 1.0 5000.0 Kampala
# Zambia   Egypt 1.0 0.0 5000.0 Kampala
# Ghana   Zambia 1.0 0.0 5000.0 Kampala
# Ghana   Egypt 1.0 0.0 5000.0 Kampala
# Nigeria   Zaire 1.0 0.0 10000.0 Kampala
# Cameroon   Senegal 1.0 0.0 35000.0 Kampala
# Ivory Coast   Zambia 1.0 0.0 3000.0 Kampala
# Ghana   Congo 2.0 1.0 15000.0 Kampala
# Ghana   Nigeria 2.0 1.0 30000.0 Kampala
# Cameroon   Ivory Coast 0.0 0.0 35000.0 Kampala
# Nigeria   Cameroon 2.0 1.0 2000.0 Kampala
# Ivory Coast   Ghana 0.0 0.0 47500.0 Kampala
# Tunisia   Mali 0.0 2.0 45000.0 Kampala
# Mali   Zaire 0.0 1.0 8000.0 Kampala
# Tunisia   Zaire 1.0 1.0 45000.0 Kampala
# Nigeria   Gabon 3.0 0.0 30000.0 Kampala
# Egypt   Gabon 4.0 0.0 6000.0 Kampala
# Nigeria   Egypt 0.0 0.0 30000.0 Kampala
# Ivory Coast   Sierra Leone 4.0 0.0 10000.0 Kampala
# Zambia   Sierra Leone 0.0 0.0 6000.0 Kampala
# Zambia   Ivory Coast 1.0 0.0 6000.0 Kampala
# Ghana   Guinea 1.0 0.0 10000.0 Kampala
# Senegal   Guinea 2.0 1.0 6000.0 Kampala
# Ghana   Senegal 1.0 0.0 6000.0 Kampala
# Zaire   Nigeria 0.0 2.0 2000.0 Kampala
# Egypt   Mali 0.0 1.0 3000.0 Kampala
# Zambia   Senegal 1.0 0.0 8000.0 Kampala
# Ghana   Ivory Coast 1.0 2.0 8000.0 Kampala
# Nigeria   Ivory Coast 2.0 2.0 2000.0 Kampala
# Zambia   Mali 4.0 0.0 2000.0 Kampala
# Ivory Coast   Mali 3.0 1.0 15000.0 Kampala
# Nigeria   Zambia 2.0 1.0 25000.0 Kampala
# South Africa   Cameroon 3.0 0.0 75000.0 Kampala
# Egypt   Angola 2.0 1.0 6000.0 Kampala
# Cameroon   Egypt 2.0 1.0 4000.0 Kampala
# South Africa   Angola 1.0 0.0 28000.0 Kampala
# South Africa   Egypt 0.0 1.0 20000.0 Kampala
# Angola   Cameroon 3.0 3.0 6000.0 Kampala
# Zambia   Algeria 0.0 0.0 9000.0 Kampala
# Sierra Leone   Burkina Faso 2.0 1.0 1500.0 Kampala
# Algeria   Sierra Leone 2.0 0.0 1500.0 Kampala
# Zambia   Burkina Faso 5.0 1.0 2000.0 Kampala
# Algeria   Burkina Faso 2.0 1.0 180.0 Kampala
# Zambia   Sierra Leone 4.0 0.0 200.0 Kampala
# Gabon   Liberia 1.0 2.0 5000.0 Kampala
# Gabon   Zaire 2.0 0.0 4000.0 Kampala
# Zaire   Liberia 2.0 0.0 3000.0 Kampala
# Ghana   Ivory Coast 2.0 0.0 8000.0 Kampala
# Tunisia   Mozambique 1.0 1.0 1000.0 Kampala
# Ghana   Tunisia 2.0 1.0 1000.0 Kampala
# Ivory Coast   Mozambique 1.0 0.0 500.0 Kampala
# Tunisia   Ivory Coast 3.0 1.0 1000.0 Kampala
# Ghana   Mozambique 2.0 0.0 3500.0 Kampala
# South Africa   Algeria 2.0 1.0 80000.0 Kampala
# Zambia   Egypt 3.0 1.0 8500.0 Kampala
# Gabon   Tunisia 1.0 1.0 4000.0 Kampala
# Ghana   Zaire 1.0 0.0 8000.0 Kampala
# South Africa   Ghana 3.0 0.0 75000.0 Kampala
# Zambia   Tunisia 2.0 4.0 5000.0 Kampala
# Ghana   Zambia 0.0 1.0 80000.0 Kampala
# South Africa   Tunisia 2.0 0.0 80000.0 Kampala
# Burkina Faso   Cameroon 0.0 1.0 30000.0 Kampala
# Algeria   Guinea 0.0 1.0 3000.0 Kampala
# Cameroon   Guinea 2.0 2.0 2000.0 Kampala
# Burkina Faso   Algeria 2.0 1.0 35000.0 Kampala
# Burkina Faso   Guinea 1.0 0.0 40000.0 Kampala
# Cameroon   Algeria 2.0 1.0 1000.0 Kampala
# DR Congo   Togo 2.0 1.0 4000.0 Kampala
# Ghana   Tunisia 2.0 0.0 12000.0 Kampala
# Tunisia   DR Congo 2.0 1.0 1000.0 Kampala
# Togo   Ghana 2.0 1.0 3000.0 Kampala
# DR Congo   Ghana 1.0 0.0 3000.0 Kampala
# Tunisia   Togo 3.0 1.0 800.0 Kampala
# South Africa   Angola 0.0 0.0 20000.0 Kampala
# Ivory Coast   Namibia 4.0 3.0 20000.0 Kampala
# Ivory Coast   South Africa 1.0 1.0 10000.0 Kampala
# Angola   Namibia 3.0 3.0 2000.0 Kampala
# Ivory Coast   Angola 5.0 2.0 4000.0 Kampala
# South Africa   Namibia 4.0 1.0 9500.0 Kampala
# Morocco   Zambia 1.0 1.0 10000.0 Kampala
# Egypt   Mozambique 2.0 0.0 20000.0 Kampala
# Egypt   Zambia 4.0 0.0 5000.0 Kampala
# Morocco   Mozambique 3.0 0.0 3000.0 Kampala
# Zambia   Mozambique 3.0 1.0 3000.0 Kampala
# Morocco   Egypt 1.0 0.0 500.0 Kampala
# Cameroon   DR Congo 0.0 1.0 5000.0 Kampala
# Tunisia   Burkina Faso 1.0 1.0 35000.0 Kampala
# Ivory Coast   Egypt 0.0 0.0 20000.0 Kampala
# Morocco   South Africa 1.0 2.0 2000.0 Kampala
# DR Congo   South Africa 1.0 2.0 4000.0 Kampala
# Burkina Faso   Egypt 0.0 2.0 40000.0 Kampala
# DR Congo   Burkina Faso 4.0 4.0 25000.0 Kampala
# South Africa   Egypt 0.0 2.0 40000.0 Kampala
# Ghana   Cameroon 1.0 1.0 45000.0 Kampala
# Ivory Coast   Togo 1.0 1.0 13000.0 Kampala
# Ghana   Togo 2.0 0.0 30000.0 Kampala
# Cameroon   Ivory Coast 3.0 0.0 5000.0 Kampala
# Ghana   Ivory Coast 0.0 2.0 40000.0 Kampala
# Cameroon   Togo 0.0 1.0 2000.0 Kampala
# South Africa   Gabon 3.0 1.0 20000.0 Kampala
# DR Congo   Algeria 0.0 0.0 7000.0 Kampala
# South Africa   DR Congo 1.0 0.0 3500.0 Kampala
# Algeria   Gabon 3.0 1.0 5000.0 Kampala
# South Africa   Algeria 1.0 1.0 2000.0 Kampala
# DR Congo   Gabon 0.0 0.0 2000.0 Kampala
# Egypt   Zambia 2.0 0.0 18000.0 Kampala
# Burkina Faso   Senegal 1.0 3.0 12000.0 Kampala
# Egypt   Senegal 1.0 0.0 30000.0 Kampala
# Zambia   Burkina Faso 1.0 1.0 5000.0 Kampala
# Egypt   Burkina Faso 4.0 2.0 17000.0 Kampala
# Zambia   Senegal 2.0 2.0 2000.0 Kampala
# Nigeria   Tunisia 4.0 2.0 80000.0 Kampala
# Morocco   Congo 1.0 0.0 8000.0 Kampala
# Nigeria   Congo 0.0 0.0 60000.0 Kampala
# Tunisia   Morocco 0.0 0.0 5000.0 Kampala
# Nigeria   Morocco 2.0 0.0 60000.0 Kampala
# Tunisia   Congo 1.0 0.0 12000.0 Kampala
# Cameroon   Algeria 2.0 1.0 15000.0 Kampala
# South Africa   Ghana 1.0 0.0 40000.0 Kampala
# Egypt   Tunisia 0.0 1.0 12000.0 Kampala
# Nigeria   Senegal 2.0 1.0 60000.0 Kampala
# Nigeria   South Africa 2.0 0.0 60000.0 Kampala
# Cameroon   Tunisia 3.0 0.0 6000.0 Kampala
# South Africa   Tunisia 2.0 2.0 1000.0 Kampala
# Nigeria   Cameroon 2.0 2.0 60000.0 Kampala
# Mali   Liberia 1.0 1.0 50000.0 Kampala
# Algeria   Nigeria 0.0 1.0 10000.0 Kampala
# Mali   Nigeria 0.0 0.0 50000.0 Kampala
# Liberia   Algeria 2.0 2.0 4000.0 Kampala
# Mali   Algeria 2.0 0.0 50000.0 Kampala
# Liberia   Nigeria 0.0 1.0 9000.0 Kampala
# South Africa   Burkina Faso 0.0 0.0 12000.0 Kampala
# Morocco   Ghana 0.0 0.0 4000.0 Kampala
# South Africa   Ghana 0.0 0.0 5000.0 Kampala
# Burkina Faso   Morocco 1.0 2.0 6000.0 Kampala
# South Africa   Morocco 3.0 1.0 3000.0 Kampala
# Burkina Faso   Ghana 1.0 2.0 15000.0 Kampala
# Cameroon   DR Congo 1.0 0.0 15000.0 Kampala
# Togo   Ivory Coast 0.0 0.0 15000.0 Kampala
# Cameroon   Ivory Coast 1.0 0.0 15000.0 Kampala
# DR Congo   Togo 0.0 0.0 7000.0 Kampala
# Cameroon   Togo 3.0 0.0 6000.0 Kampala
# DR Congo   Ivory Coast 3.0 1.0 12000.0 Kampala
# Egypt   Senegal 0.0 1.0 20000.0 Kampala
# Zambia   Tunisia 0.0 0.0 6000.0 Kampala
# Egypt   Tunisia 1.0 0.0 3000.0 Kampala
# Senegal   Zambia 1.0 0.0 20000.0 Kampala
# Egypt   Zambia 2.0 1.0 10000.0 Kampala
# Senegal   Tunisia 0.0 0.0 8000.0 Kampala
# South Africa   Mali 0.0 2.0 15000.0 Kampala
# Nigeria   Ghana 1.0 0.0 25000.0 Kampala
# Cameroon   Egypt 1.0 0.0 15000.0 Kampala
# Senegal   DR Congo 2.0 0.0 25000.0 Kampala
# Nigeria   Senegal 1.0 2.0 20000.0 Kampala
# Mali   Cameroon 0.0 3.0 50000.0 Kampala
# Nigeria   Mali 1.0 0.0 15000.0 Kampala
# Senegal   Cameroon 0.0 0.0 50000.0 Kampala
# Tunisia   Rwanda 2.0 1.0 60000.0 Kampala
# DR Congo   Guinea 1.0 2.0 2000.0 Kampala
# Rwanda   Guinea 1.0 1.0 4000.0 Kampala
# Tunisia   DR Congo 3.0 0.0 60000.0 Kampala
# Tunisia   Guinea 1.0 1.0 35000.0 Kampala
# Rwanda   DR Congo 1.0 0.0 700.0 Kampala
# Kenya   Mali 1.0 3.0 6000.0 Kampala
# Senegal   Burkina Faso 0.0 0.0 2000.0 Kampala
# Senegal   Kenya 3.0 0.0 13500.0 Kampala
# Burkina Faso   Mali 1.0 3.0 1500.0 Kampala
# Senegal   Mali 1.0 1.0 7550.0 Kampala
# Burkina Faso   Kenya 0.0 3.0 4550.0 Kampala
# Zimbabwe   Egypt 1.0 2.0 22000.0 Kampala
# Cameroon   Algeria 1.0 1.0 20000.0 Kampala
# Cameroon   Zimbabwe 5.0 3.0 15000.0 Kampala
# Algeria   Egypt 2.0 1.0 15000.0 Kampala
# Cameroon   Egypt 0.0 0.0 20000.0 Kampala
# Algeria   Zimbabwe 1.0 2.0 10000.0 Kampala
# Nigeria   Morocco 0.0 1.0 15000.0 Kampala
# South Africa   Benin 2.0 0.0 12000.0 Kampala
# Nigeria   South Africa 4.0 0.0 15000.0 Kampala
# Morocco   Benin 4.0 0.0 20000.0 Kampala
# Morocco   South Africa 1.0 1.0 6000.0 Kampala
# Nigeria   Benin 2.0 1.0 15000.0 Kampala
# Mali   Guinea 2.0 1.0 1450.0 Kampala
# Tunisia   Senegal 1.0 0.0 57000.0 Kampala
# Cameroon   Nigeria 1.0 2.0 14750.0 Kampala
# Morocco   Algeria 3.0 1.0 22000.0 Kampala
# Tunisia   Nigeria 1.0 1.0 56000.0 Kampala
# Morocco   Mali 4.0 0.0 15000.0 Kampala
# Nigeria   Mali 2.0 1.0 2500.0 Kampala
# Tunisia   Morocco 2.0 1.0 65000.0 Kampala
# Egypt   Libya 3.0 0.0 65000.0 Kampala
# Morocco   Ivory Coast 0.0 1.0 8000.0 Kampala
# Libya   Ivory Coast 1.0 2.0 42000.0 Kampala
# Egypt   Morocco 0.0 0.0 67000.0 Kampala
# Egypt   Ivory Coast 3.0 1.0 74000.0 Kampala
# Libya   Morocco 0.0 0.0 5000.0 Kampala
# Cameroon   Angola 3.0 1.0 8000.0 Kampala
# Togo   DR Congo 0.0 2.0 6000.0 Kampala
# Angola   DR Congo 0.0 0.0 2000.0 Kampala
# Cameroon   Togo 2.0 0.0 3000.0 Kampala
# Angola   Togo 3.0 2.0 4000.0 Kampala
# Cameroon   DR Congo 2.0 0.0 5000.0 Kampala
# Tunisia   Zambia 4.0 1.0 16000.0 Kampala
# South Africa   Guinea 0.0 2.0 10000.0 Kampala
# Zambia   Guinea 1.0 2.0 24000.0 Kampala
# Tunisia   South Africa 2.0 0.0 10000.0 Kampala
# Tunisia   Guinea 0.0 3.0 18000.0 Kampala
# Zambia   South Africa 1.0 0.0 4000.0 Kampala
# Nigeria   Ghana 1.0 0.0 18000.0 Kampala
# Zimbabwe   Senegal 0.0 2.0 15000.0 Kampala
# Ghana   Senegal 1.0 0.0 18000.0 Kampala
# Nigeria   Zimbabwe 2.0 0.0 10000.0 Kampala
# Nigeria   Senegal 2.0 1.0 17000.0 Kampala
# Ghana   Zimbabwe 1.0 2.0 18500.0 Kampala
# Guinea   Senegal 2.0 3.0 17000.0 Kampala
# Egypt   DR Congo 4.0 1.0 74000.0 Kampala
# Nigeria   Tunisia 1.0 1.0 10000.0 Kampala
# Cameroon   Ivory Coast 1.0 1.0 4000.0 Kampala
# Egypt   Senegal 2.0 1.0 74100.0 Kampala
# Nigeria   Ivory Coast 0.0 1.0 20000.0 Kampala
# Senegal   Nigeria 0.0 1.0 11354.0 Kampala
# Egypt   Ivory Coast 0.0 0.0 74100.0 Kampala
# Ghana   Guinea 2.0 1.0 35000.0 Kampala
# Namibia   Morocco 1.0 5.0 2000.0 Kampala
# Guinea   Morocco 3.0 2.0 15000.0 Kampala
# Ghana   Namibia 1.0 0.0 40000.0 Kampala
# Ghana   Morocco 2.0 0.0 40000.0 Kampala
# Guinea   Namibia 1.0 1.0 1000.0 Kampala
# Nigeria   Ivory Coast 0.0 1.0 20088.0 Kampala
# Mali   Benin 1.0 0.0 11000.0 Kampala
# Ivory Coast   Benin 4.0 1.0 13000.0 Kampala
# Nigeria   Mali 0.0 0.0 16000.0 Kampala
# Nigeria   Benin 2.0 0.0 4000.0 Kampala
# Ivory Coast   Mali 3.0 0.0 20000.0 Kampala
# Egypt   Cameroon 4.0 2.0 42000.0 Kampala
# Sudan   Zambia 0.0 3.0 35000.0 Kampala
# Cameroon   Zambia 5.0 1.0 10000.0 Kampala
# Egypt   Sudan 3.0 0.0 15000.0 Kampala
# Cameroon   Sudan 3.0 0.0 10000.0 Kampala
# Egypt   Zambia 1.0 1.0 2000.0 Kampala
# Tunisia   Senegal 2.0 2.0 12000.0 Kampala
# South Africa   Angola 1.0 1.0 15000.0 Kampala
# Senegal   Angola 1.0 3.0 10000.0 Kampala
# Tunisia   South Africa 3.0 1.0 15000.0 Kampala
# Senegal   South Africa 1.0 1.0 15000.0 Kampala
# Tunisia   Angola 0.0 0.0 10000.0 Kampala
# Ghana   Nigeria 2.0 1.0 45000.0 Kampala
# Ivory Coast   Guinea 5.0 0.0 14000.0 Kampala
# Egypt   Angola 2.0 1.0 6000.0 Kampala
# Tunisia   Cameroon 2.0 3.0 15000.0 Kampala
# Ghana   Cameroon 0.0 1.0 40000.0 Kampala
# Ivory Coast   Egypt 1.0 4.0 30000.0 Kampala
# Ghana   Ivory Coast 4.0 2.0 40000.0 Kampala
# Cameroon   Egypt 0.0 1.0 35500.0 Kampala
# Angola   Mali 4.0 4.0 45000.0 Kampala
# Malawi   Algeria 3.0 0.0 1000.0 Kampala
# Mali   Algeria 0.0 1.0 4000.0 Kampala
# Angola   Malawi 2.0 0.0 48500.0 Kampala
# Angola   Algeria 0.0 0.0 40000.0 Kampala
# Mali   Malawi 3.0 1.0 21000.0 Kampala
# Ivory Coast   Burkina Faso 0.0 0.0 5000.0 Kampala
# Ghana   Togo nan nan nan Kampala
# Burkina Faso   Togo nan nan nan Kampala
# Ivory Coast   Ghana 3.0 1.0 23000.0 Kampala
# Burkina Faso   Ghana 0.0 1.0 8000.0 Kampala
# Ivory Coast   Togo nan nan nan Kampala
# Egypt   Nigeria 3.0 1.0 18000.0 Kampala
# Mozambique   Benin 2.0 2.0 15000.0 Kampala
# Nigeria   Benin 1.0 0.0 8000.0 Kampala
# Egypt   Mozambique 2.0 0.0 16000.0 Kampala
# Egypt   Benin 2.0 0.0 12500.0 Kampala
# Nigeria   Mozambique 3.0 0.0 8050.0 Kampala
# Cameroon   Gabon 0.0 1.0 15000.0 Kampala
# Zambia   Tunisia 1.0 1.0 17000.0 Kampala
# Gabon   Tunisia 0.0 0.0 16000.0 Kampala
# Cameroon   Zambia 3.0 2.0 15000.0 Kampala
# Gabon   Zambia 1.0 2.0 11065.0 Kampala
# Cameroon   Tunisia 2.0 2.0 19000.0 Kampala
# Angola   Ghana 0.0 1.0 50000.0 Kampala
# Ivory Coast   Algeria 2.0 3.0 10000.0 Kampala
# Egypt   Cameroon 3.0 1.0 12000.0 Kampala
# Zambia   Nigeria 0.0 0.0 10000.0 Kampala
# Ghana   Nigeria 1.0 0.0 7500.0 Kampala
# Algeria   Egypt 0.0 4.0 25000.0 Kampala
# Nigeria   Algeria 1.0 0.0 12000.0 Kampala
# Ghana   Egypt 0.0 1.0 45000.0 Kampala
# Zambia   Sudan 3.0 0.0 200.0 Kampala
# Ivory Coast   Equatorial Guinea 3.0 0.0 12500.0 Kampala
# Gabon   Mali 1.0 1.0 30000.0 Kampala
# Ghana   Tunisia 2.0 1.0 8000.0 Kampala
# Zambia   Ghana 1.0 0.0 12000.0 Kampala
# Mali   Ivory Coast 0.0 1.0 32000.0 Kampala
# Ghana   Mali 0.0 2.0 15000.0 Kampala
# Zambia   Ivory Coast 0.0 0.0 40000.0 Kampala
# Ghana   Cape Verde 2.0 0.0 8000.0 Kampala
# South Africa   Mali 1.0 1.0 45000.0 Kampala
# Ivory Coast   Nigeria 1.0 2.0 25000.0 Kampala
# Burkina Faso   Togo 1.0 0.0 27000.0 Kampala
# Mali   Nigeria 1.0 4.0 54000.0 Kampala
# Burkina Faso   Ghana 1.0 1.0 35000.0 Kampala
# Mali   Ghana 3.0 1.0 6000.0 Kampala
# Nigeria   Burkina Faso 1.0 0.0 85000.0 Kampala
# Congo   DR Congo 2.0 4.0 31670.0 Kampala
# Tunisia   Equatorial Guinea 1.0 2.0 41000.0 Kampala
# Ghana   Guinea 3.0 0.0 14500.0 Kampala
# Ivory Coast   Algeria 3.0 1.0 15000.0 Kampala
# DR Congo   Ivory Coast 1.0 3.0 30000.0 Kampala
# Ghana   Equatorial Guinea 3.0 0.0 15520.0 Kampala
# DR Congo   Equatorial Guinea 0.0 0.0 15520.0 Kampala
# Ivory Coast   Ghana 0.0 0.0 32857.0 Kampala
# Gabon   Guinea-Bissau 1.0 1.0 39230.0 Kampala
# Burkina Faso   Cameroon 1.0 1.0 20720.0 Kampala
# Gabon   Burkina Faso 1.0 1.0 38250.0 Kampala
# Cameroon   Guinea-Bissau 2.0 1.0 nan Kampala
# Cameroon   Gabon 0.0 0.0 nan Kampala
# Guinea-Bissau   Burkina Faso 0.0 2.0 nan Kampala
# Algeria   Zimbabwe 2.0 2.0 nan Kampala
# Tunisia   Senegal 0.0 2.0 nan Kampala
# Algeria   Tunisia 1.0 2.0 nan Kampala
# Senegal   Zimbabwe 2.0 0.0 nan Kampala
# Senegal   Algeria 2.0 2.0 nan Kampala
# Zimbabwe   Tunisia 2.0 4.0 nan Kampala
# Ivory Coast   Togo 0.0 0.0 nan Kampala
# DR Congo   Morocco 1.0 0.0 nan Kampala
# Ivory Coast   DR Congo 2.0 2.0 nan Kampala
# Morocco   Togo 3.0 1.0 nan Kampala
# Morocco   Ivory Coast 1.0 0.0 nan Kampala
# Togo   DR Congo 1.0 3.0 nan Kampala
# Ghana   Uganda 1.0 0.0 nan Kampala
# Mali   Egypt 0.0 0.0 nan Kampala
# Ghana   Mali 1.0 0.0 nan Kampala
# Egypt   Uganda 1.0 0.0 nan Kampala
# Egypt   Ghana 1.0 0.0 nan Kampala
# Uganda   Mali 1.0 1.0 nan Kampala
# Burkina Faso   Tunisia 2.0 0.0 nan Kampala
# Senegal   Cameroon 0.0 0.0 nan Kampala
# DR Congo   Ghana 1.0 2.0 nan Kampala
# Egypt   Morocco 1.0 0.0 nan Kampala
# Burkina Faso   Egypt 1.0 1.0 nan Kampala
# Cameroon   Ghana 2.0 0.0 nan Kampala
# Burkina Faso   Ghana 1.0 0.0 nan Kampala
# Egypt   Cameroon 1.0 2.0 nan Kampala
# Egypt   Zimbabwe 1.0 0.0 73299.0 Kampala
# DR Congo   Uganda 0.0 2.0 1083.0 Kampala
# Uganda   Zimbabwe 1.0 1.0 73589.0 Kampala
# Egypt   DR Congo 2.0 0.0 74219.0 Kampala
# Uganda   Egypt 0.0 2.0 74566.0 Kampala
# Zimbabwe   DR Congo 0.0 4.0 4364.0 Kampala
# Nigeria   Burundi 1.0 0.0 3192.0 Kampala
# Guinea   Madagascar 2.0 2.0 5342.0 Kampala
# Nigeria   Guinea 1.0 0.0 10388.0 Kampala
# Madagascar   Burundi 1.0 0.0 4900.0 Kampala
# Madagascar   Nigeria 2.0 0.0 9895.0 Kampala
# Burundi   Guinea 0.0 2.0 5753.0 Kampala
# Senegal   Tanzania 2.0 0.0 7249.0 Kampala
# Algeria   Kenya 2.0 0.0 8071.0 Kampala
# Senegal   Algeria 0.0 1.0 25765.0 Kampala
# Kenya   Tanzania 3.0 2.0 7233.0 Kampala
# Kenya   Senegal 0.0 3.0 13224.0 Kampala
# Tanzania   Algeria 0.0 3.0 8921.0 Kampala
# Morocco   Namibia 1.0 0.0 6857.0 Kampala
# Ivory Coast   South Africa 1.0 0.0 4961.0 Kampala
# Morocco   Ivory Coast 1.0 0.0 27500.0 Kampala
# South Africa   Namibia 1.0 0.0 16090.0 Kampala
# South Africa   Morocco 0.0 1.0 12098.0 Kampala
# Namibia   Ivory Coast 1.0 4.0 7530.0 Kampala
# Tunisia   Angola 1.0 1.0 7345.0 Kampala
# Mali   Mauritania 4.0 1.0 6202.0 Kampala
# Tunisia   Mali 1.0 1.0 16085.0 Kampala
# Mauritania   Angola 0.0 0.0 10120.0 Kampala
# Mauritania   Tunisia 0.0 0.0 7732.0 Kampala
# Angola   Mali 0.0 1.0 8135.0 Kampala
# Cameroon   Guinea-Bissau 2.0 0.0 5983.0 Kampala
# Ghana   Benin 2.0 2.0 8094.0 Kampala
# Cameroon   Ghana 0.0 0.0 16724.0 Kampala
# Benin   Guinea-Bissau 0.0 0.0 9212.0 Kampala
# Benin   Cameroon 0.0 0.0 14120.0 Kampala
# Guinea-Bissau   Ghana 0.0 2.0 6905.0 Kampala
# Morocco   Benin 1.0 1.0 7500.0 Kampala
# Uganda   Senegal 0.0 1.0 6950.0 Kampala
# Nigeria   Cameroon 3.0 2.0 10000.0 Kampala
# Egypt   South Africa 0.0 1.0 75000.0 Kampala
# Madagascar   DR Congo 2.0 2.0 5890.0 Kampala
# Algeria   Guinea 3.0 0.0 8205.0 Kampala
# Mali   Ivory Coast 0.0 1.0 7672.0 Kampala
# Ghana   Tunisia 1.0 1.0 8890.0 Kampala

# %%
# Change the order of DataFrame columns
df = df[['AwayTeam', 'HomeTeam', 'AwayTeamGoals', 'HomeTeamGoals', 'Stadium', 'Attendance']]
print(df)
# Out:
#           AwayTeam     HomeTeam  AwayTeamGoals  HomeTeamGoals  \
# 0            Egypt       Sudan             2.0            1.0
# 1     South Africa    Ethiopia             NaN            NaN
# 2         Ethiopia       Egypt            10.0            4.0
# 3         Ethiopia        Egypt            0.0            4.0
# 4         Ethiopia       Sudan             0.0            1.0
# ..             ...          ...            ...            ...
# 609   South Africa       Egypt             1.0            0.0
# 610       DR Congo  Madagascar             2.0            2.0
# 611         Guinea     Algeria             0.0            3.0
# 612    Ivory Coast        Mali             1.0            0.0
# 613        Tunisia       Ghana             1.0            1.0
#
#                          Stadium  Attendance
# 0              Municipal Stadium     30000.0
# 1                            NaN         NaN
# 2              Municipal Stadium     30000.0
# 3          Prince Farouk Stadium     30000.0
# 4          Prince Farouk Stadium     20000.0
# ..                           ...         ...
# 609  Cairo International Stadium     75000.0
# 610           Alexandria Stadium      5890.0
# 611              30 June Stadium      8205.0
# 612                 Suez Stadium      7672.0
# 613             Ismailia Stadium      8890.0
#
# [614 rows x 6 columns]

# %%
# Delete DataFrame row(s) whose value is 0 in the 'HomeTeamGoals' column
df = df[df.HomeTeamGoals != 0]
print(df)
# Out:
#           AwayTeam     HomeTeam  AwayTeamGoals  HomeTeamGoals  \
# 0            Egypt       Sudan             2.0            1.0
# 1     South Africa    Ethiopia             NaN            NaN
# 2         Ethiopia       Egypt            10.0            4.0
# 3         Ethiopia        Egypt            0.0            4.0
# 4         Ethiopia       Sudan             0.0            1.0
# ..             ...          ...            ...            ...
# 606          Benin     Morocco             1.0            1.0
# 608       Cameroon     Nigeria             2.0            3.0
# 610       DR Congo  Madagascar             2.0            2.0
# 611         Guinea     Algeria             0.0            3.0
# 613        Tunisia       Ghana             1.0            1.0
#
#                    Stadium  Attendance
# 0        Municipal Stadium     30000.0
# 1                      NaN         NaN
# 2        Municipal Stadium     30000.0
# 3    Prince Farouk Stadium     30000.0
# 4    Prince Farouk Stadium     20000.0
# ..                     ...         ...
# 606       Al Salam Stadium      7500.0
# 608     Alexandria Stadium     10000.0
# 610     Alexandria Stadium      5890.0
# 611        30 June Stadium      8205.0
# 613       Ismailia Stadium      8890.0
#
# [489 rows x 6 columns]
