# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#control display of seaborn data
pd.options.display.max_columns = 50
sns.set(style='darkgrid', rc={"axes.facecolor": "#CAF1DE"})

# %%
#load the dataset
df_4 = pd.read_csv('datasets/bse_dataset4.csv')
df_4
# Out:
#                Timestamp         gender   Age  emotion   YOB     CGPA  \
# 0    05/07/2023 09:38:39           Male  21.0  Content  2002     4.22
# 1    05/07/2023 09:38:57  Marabou stock  45.0    Weird  2100      8.9
# 2    05/07/2023 09:39:09        Female   20.0    Happy  2002     3.98
# 3    05/07/2023 09:39:12           Male  21.0    Happy  2003     4.37
# 4    05/07/2023 09:39:14         Female  21.0    Happy  2002     3.63
# ..                   ...            ...   ...      ...   ...      ...
# 164  05/07/2023 09:44:09           Male  22.0   Angry   1999      3.5
# 165  05/07/2023 09:44:14           male  23.0      sad  1999        4
# 166  05/07/2023 09:44:15           male  20.0     calm  2002      3.7
# 167  05/07/2023 09:44:35         Female  21.0      sad  2001      3.8
# 168  05/07/2023 09:45:13         Female  20.0    Happy  2022  4......
#
#     Do you have a Girl Friend or BOY Friend Do you have Depression?  \
# ...

# %%
#shape of the dataset
df_4.shape
# Out:
# (169, 15)

# %%
#colums of the dataset
df_4.columns
# Out:
# Index(['Timestamp', 'gender', 'Age', 'emotion', 'YOB', 'CGPA',
#        'Do you have a Girl Friend or BOY Friend', 'Do you have Depression?',
#        'Do you have Anxiety?', 'Do you have Panic attack?',
#        'Did you have seek any specialist for a treatment? ', 'Duration',
#        'Pulse', 'Maxpulse', 'Calories'],
#       dtype='object')

# %%
#drop empty columns
df_4.dropna(inplace=True)
df_4.shape
# Out:
# (160, 15)

# %%
#using fillna() to fill empty values
df_4['Calories'].fillna(value = 100, inplace=True)
df_4.shape
# Out:
# (160, 15)

# %%
print(df_4.to_string())
# Out:
#                Timestamp         gender   Age               emotion            YOB              CGPA Do you have a Girl Friend or BOY Friend Do you have Depression? Do you have Anxiety? Do you have Panic attack? Did you have seek any specialist for a treatment?   Duration  Pulse  Maxpulse  Calories
# 0    05/07/2023 09:38:39           Male  21.0               Content           2002              4.22                                      No                      No                  Yes                       Yes                                                Yes        60    110       130     409.1
# 1    05/07/2023 09:38:57  Marabou stock  45.0                 Weird           2100               8.9                                     Yes                     Yes                  Yes                       Yes                                                 No        60    117       145     479.0
# ...

# %%
#to fill in the mean value of the column
df_4['Calories'].fillna(value = df_4['Calories'].mean(), inplace=True)
df_4.shape
# Out:
# (160, 15)

# %%
#for the Age column
m = df_4['Age'].mean()
df_4['Age'].fillna(value = m, inplace=True)
print(df_4.to_string())
# Out:
#                Timestamp         gender   Age               emotion            YOB              CGPA Do you have a Girl Friend or BOY Friend Do you have Depression? Do you have Anxiety? Do you have Panic attack? Did you have seek any specialist for a treatment?   Duration  Pulse  Maxpulse  Calories
# 0    05/07/2023 09:38:39           Male  21.0               Content           2002              4.22                                      No                      No                  Yes                       Yes                                                Yes        60    110       130     409.1
# 1    05/07/2023 09:38:57  Marabou stock  45.0                 Weird           2100               8.9                                     Yes                     Yes                  Yes                       Yes                                                 No        60    117       145     479.0
# ...

# %%
# Return rows with the mean value of the column Age
df_4[df_4['Age'] == m]
# Out:
# Empty DataFrame
# Columns: [Timestamp, gender, Age, emotion, YOB, CGPA, Do you have a Girl Friend or BOY Friend, Do you have Depression?, Do you have Anxiety?, Do you have Panic attack?, Did you have seek any specialist for a treatment? , Duration, Pulse, Maxpulse, Calories]
# Index: []

# %%
# Set the option to display all rows
pd.set_option('display.max_rows', None)

# %%
#calculate median
med = df_4['Calories'].median()
print(med)
df_4['Calories'].fillna(value = med, inplace=True)
print(df_4)
# Out:
# 317.85
#                Timestamp         gender   Age               emotion  \
# 0    05/07/2023 09:38:39           Male  21.0               Content
# 1    05/07/2023 09:38:57  Marabou stock  45.0                 Weird
# 2    05/07/2023 09:39:09        Female   20.0                 Happy
# 3    05/07/2023 09:39:12           Male  21.0                 Happy
# 4    05/07/2023 09:39:14         Female  21.0                 Happy
# 6    05/07/2023 09:39:21         female  21.0            irritated
# 7    05/07/2023 09:39:23        Female   22.0  In a state of wonder
# 8    05/07/2023 09:39:26           Male  22.0                   Sad
# 9    05/07/2023 09:39:27         Female  20.0                 happy
# 10            2023/12/26           Male  24.0                 Happy
# 11   05/07/2023 09:39:27         Female  20.0                 happy
# 12   05/07/2023 09:39:38           Male  25.0                 Happy
# 13   05/07/2023 09:39:40           MALE  22.0                  fine
# ...

# %%
#calculating the mode on age
mode = df_4['Age'].mode()
print(mode)
df_4['Age'].fillna(value = mode, inplace=True)
print(df_4)
# Out:
# 0    21.0
# Name: Age, dtype: float64
#                Timestamp         gender   Age               emotion  \
# 0    05/07/2023 09:38:39           Male  21.0               Content
# 1    05/07/2023 09:38:57  Marabou stock  45.0                 Weird
# 2    05/07/2023 09:39:09        Female   20.0                 Happy
# 3    05/07/2023 09:39:12           Male  21.0                 Happy
# 4    05/07/2023 09:39:14         Female  21.0                 Happy
# 6    05/07/2023 09:39:21         female  21.0            irritated
# 7    05/07/2023 09:39:23        Female   22.0  In a state of wonder
# 8    05/07/2023 09:39:26           Male  22.0                   Sad
# 9    05/07/2023 09:39:27         Female  20.0                 happy
# 10            2023/12/26           Male  24.0                 Happy
# 11   05/07/2023 09:39:27         Female  20.0                 happy
# 12   05/07/2023 09:39:38           Male  25.0                 Happy
# ...

# %%
#wrong formats in rows that need to be removed
df_4['Timestamp'].fillna("08/07/2023 09:45:13", inplace=True)
print(df_4['Timestamp'])
# Out:
# 0      05/07/2023 09:38:39
# 1      05/07/2023 09:38:57
# 2      05/07/2023 09:39:09
# 3      05/07/2023 09:39:12
# 4      05/07/2023 09:39:14
# 6      05/07/2023 09:39:21
# 7      05/07/2023 09:39:23
# 8      05/07/2023 09:39:26
# 9      05/07/2023 09:39:27
# 10              2023/12/26
# 11     05/07/2023 09:39:27
# 12     05/07/2023 09:39:38
# 13     05/07/2023 09:39:40
# 14     05/07/2023 09:39:45
# 15     05/07/2023 09:39:46
# 16     05/07/2023 09:39:46
# 18     05/07/2023 09:39:49
# 19     05/07/2023 09:39:50
# 20     05/07/2023 09:39:54
# 21     05/07/2023 09:39:56
# 22     05/07/2023 09:40:00
# 23     05/07/2023 09:40:00
# 24              2023/12/26
# 25     05/07/2023 09:40:02
# 26     05/07/2023 09:40:08
# 28     05/07/2023 09:40:10
# 29     05/07/2023 09:40:10
# 30     05/07/2023 09:40:12
# 31     05/07/2023 09:40:13
# 32     05/07/2023 09:40:16
# 33     05/07/2023 09:40:25
# 34     05/07/2023 09:40:26
# 35     05/07/2023 09:40:27
# 36     05/07/2023 09:40:33
# ...

# %%
#check if format is correct
df_4['Timestamp'] = pd.to_datetime(df_4['Timestamp'])
print(df_4['Timestamp'])
# Out:
# 0     2023-05-07 09:38:39
# 1     2023-05-07 09:38:57
# 2     2023-05-07 09:39:09
# 3     2023-05-07 09:39:12
# 4     2023-05-07 09:39:14
# 6     2023-05-07 09:39:21
# 7     2023-05-07 09:39:23
# 8     2023-05-07 09:39:26
# 9     2023-05-07 09:39:27
# 10    2023-12-26 00:00:00
# 11    2023-05-07 09:39:27
# 12    2023-05-07 09:39:38
# 13    2023-05-07 09:39:40
# 14    2023-05-07 09:39:45
# 15    2023-05-07 09:39:46
# 16    2023-05-07 09:39:46
# 18    2023-05-07 09:39:49
# 19    2023-05-07 09:39:50
# 20    2023-05-07 09:39:54
# 21    2023-05-07 09:39:56
# 22    2023-05-07 09:40:00
# 23    2023-05-07 09:40:00
# 24    2023-12-26 00:00:00
# 25    2023-05-07 09:40:02
# 26    2023-05-07 09:40:08
# 28    2023-05-07 09:40:10
# 29    2023-05-07 09:40:10
# 30    2023-05-07 09:40:12
# 31    2023-05-07 09:40:13
# 32    2023-05-07 09:40:16
# 33    2023-05-07 09:40:25
# 34    2023-05-07 09:40:26
# 35    2023-05-07 09:40:27
# 36    2023-05-07 09:40:33
# 37    2023-05-07 09:40:34
# ...

# %%
# dealing with wrong data
for x in df_4.index:
    if df_4.loc[x, 'gender'] == "Marabou stock":
        df_4.drop(x, inplace=True)
print(df_4['gender'])
df_4.shape
# Out:
# 0         Male
# 2      Female
# 3         Male
# 4       Female
# 6       female
# 7      Female
# 8         Male
# 9       Female
# 10        Male
# 11      Female
# 12        Male
# 13        MALE
# 14      FEMALE
# 15        Male
# 16      Female
# 18        Male
# 19        Male
# 20      FEMALE
# 21        Male
# 22        Male
# 23        male
# 24      Female
# 25      Female
# 26        Male
# 28     Female
# 29        Male
# 30        Male
# 31      Female
# 32        male
# 33        male
# 34        Male
# 35        Male
# 36        male
# 37        Male
# 38      Female
# 39        male
# 40     Female
# 41        male
# 42        male
# 43        Male
# 44        Male
# 45      female
# 47     Female
# 48        Male
# 49        Male
# 50        Male
# 51        Male
# 52      female
# 53        Male
# 54        Male
# 55        Male
# 56     Female
# 57         Yes
# 58        male
# 59      Female
# 60        Male
# 61        Male
# 62      Female
# 63        male
# ...

# %%
#duplicates
print(df_4.duplicated())
df_4.drop_duplicates(inplace= True)
# Out:
# 0      False
# 2      False
# 3      False
# 4      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11      True
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 28     False
# 29     False
# 30     False
# 31     False
# 32     False
# 33     False
# 34     False
# 35     False
# 36     False
# 37     False
# 38     False
# 39     False
# 40     False
# 41     False
# 42     False
# 43     False
# 44     False
# 45     False
# 47     False
# 48     False
# 49     False
# 50     False
# 51     False
# 52     False
# 53     False
# 54     False
# 55     False
# 56     False
# 57     False
# 58     False
# 59     False
# 60     False
# 61     False
# 62     False
# 63     False
# 64     False
# 65     False
# 66     False
# 67     False
# 68     False
# 69     False
# 70     False
# ...

# %%
print(df_4.duplicated())
# Out:
# 0      False
# 2      False
# 3      False
# 4      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 28     False
# 29     False
# 30     False
# 31     False
# 32     False
# 33     False
# 34     False
# 35     False
# 36     False
# 37     False
# 38     False
# 39     False
# 40     False
# 41     False
# 42     False
# 43     False
# 44     False
# 45     False
# 47     False
# 48     False
# 49     False
# 50     False
# 51     False
# 52     False
# 53     False
# 54     False
# 55     False
# 56     False
# 57     False
# 58     False
# 59     False
# 60     False
# 61     False
# 62     False
# 63     False
# 64     False
# 65     False
# 66     False
# 67     False
# 68     False
# 69     False
# 70     False
# 71     False
# ...

# %%
#plotting a histogram for Age
df_4['Age'].plot(kind='hist', figsize=(10,10))
# Out:
# <AxesSubplot:ylabel='Frequency'>
